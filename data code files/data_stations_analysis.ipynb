# %% [markdown]
# ## pips and includes

# %%
import pandas as pd
import requests
import json
from datetime import datetime
import os

# %% [markdown]
# ## Constants

# %%
DATA_DIRECTORY = "../data/"

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### missing data analysis

# %%
def calculate_missing_percentage(csv_path):
    df = pd.read_csv(csv_path, na_values=['None', 'null', '-', '', ' ', 'NaN', 'nan', 'NAN'], low_memory=False)
    missing_percentages = df.isnull().mean() * 100
    return missing_percentages

def process_missing_data(data_directory):
    missing_data = {}
    for filename in os.listdir(data_directory):
        if filename.endswith(".csv"):
            file_path = os.path.join(data_directory, filename)
            station_name = filename.replace('_data_2000_2023.csv', '')
            missing_data[station_name] = calculate_missing_percentage(file_path)
    
    missing_data_df = pd.DataFrame(missing_data).transpose()
    missing_data_df.fillna(100, inplace=True)
    missing_data_df['Average Percentage'] = missing_data_df.mean(axis=1)
    
    columns_to_exclude = ['BP (hPa)', 'Date Time', 'DiffR (w/m^2)', 'Grad (w/m^2)', 'NIP']
    columns_to_include = [col for col in missing_data_df.columns if col not in columns_to_exclude]
    
    missing_data_df['Average Percentage Excluding Specific Columns'] = missing_data_df[columns_to_include].mean(axis=1)
    missing_data_df = missing_data_df.sort_values(by='Average Percentage Excluding Specific Columns')
    missing_data_df = missing_data_df.round(1)
    
    return missing_data_df

missing_data_df = process_missing_data(DATA_DIRECTORY)

# %%
missing_data_df
# Out:
#                     BP (hPa)  Date Time  DiffR (w/m^2)  Grad (w/m^2)  \
# Dafna                  100.0        0.0          100.0         100.0
# Kefar Blum             100.0        0.0          100.0         100.0
# Eshhar                 100.0        0.0          100.0         100.0
# Shave Ziyyon           100.0        0.0          100.0         100.0
# Merom Golan Picman     100.0        0.0          100.0           4.4
# Gamla                  100.0        0.0          100.0          74.7
# Kefar Giladi           100.0        0.0          100.0         100.0
# Kefar Nahum            100.0        0.0          100.0         100.0
# Avne Etan              100.0        0.0          100.0         100.0
# Elon                   100.0        0.0          100.0         100.0
# Bet Zayda              100.0        0.0          100.0         100.0
# Rosh Haniqra           100.0        0.0          100.0         100.0
# Zefat Har Kenaan        28.5        0.0          100.0         100.0
# Afeq                    37.8        0.0          100.0         100.0
# Harashim               100.0        0.0          100.0         100.0
# Haifa Technion         100.0        0.0            6.2           2.7
# Deir Hanna             100.0        0.0          100.0         100.0
# Ammiad                 100.0        0.0          100.0         100.0
# Ayyelet Hashahar       100.0        0.0          100.0         100.0
# Haifa Refineries       100.0        0.0          100.0         100.0
#
#                     NIP (w/m^2)  RH (%)  Rain  STDwd (deg)  TD (degC)  \
# Dafna                     100.0     0.1   0.0          0.0        0.1
# Kefar Blum                100.0     1.0   0.0          0.1        0.2
# Eshhar                    100.0     0.5   0.7          0.1        0.3
# Shave Ziyyon              100.0     2.7   0.5          0.4        0.3
# Merom Golan Picman        100.0     6.5   3.0          0.7        0.0
# Gamla                     100.0     1.0   0.4          0.3        0.1
# Kefar Giladi              100.0     0.4   2.4          1.7        0.1
# Kefar Nahum               100.0     1.7   0.0          0.0        2.2
# Avne Etan                 100.0     3.0   0.3          0.6        0.1
# Elon                      100.0    10.1   7.9          0.4        0.4
# Bet Zayda                 100.0     5.6   2.0          0.5        0.4
# Rosh Haniqra              100.0     9.2  20.3          4.4        0.9
# Zefat Har Kenaan          100.0    11.4  11.2          8.0        1.6
# Afeq                      100.0    11.0   4.3         12.1        1.9
# Harashim                  100.0     3.7   1.0         15.9        0.3
# Haifa Technion             23.6    12.3  29.9         25.6        0.4
# Deir Hanna                100.0     2.0   1.1         35.9        1.9
# Ammiad                    100.0     1.3   8.0         45.2        1.3
# Ayyelet Hashahar          100.0     0.4   1.1        100.0        0.1
# Haifa Refineries          100.0     6.7   3.2        100.0        0.2
#
#                     TDmax (degC)  TDmin (degC)   Time  WD (deg)  WDmax (deg)  \
# Dafna                        0.1           0.1    0.0       0.0          0.0
# Kefar Blum                   0.2           0.2    0.0       0.2          0.2
# Eshhar                       0.3           0.3    0.0       0.2          0.2
# Shave Ziyyon                 0.3           0.3    0.2       0.4          0.4
# Merom Golan Picman           0.1           0.1    0.4       1.1          1.2
# Gamla                        0.1           0.1    5.7       0.5          0.5
# Kefar Giladi                 0.1           0.1    0.1       1.8          1.8
# Kefar Nahum                  2.1           2.2    3.6       0.0          0.0
# Avne Etan                    0.1           0.1    2.3       0.9          0.9
# Elon                         0.4           0.4    0.3       0.4          0.5
# Bet Zayda                    0.4           0.4    4.4       4.8          4.8
# Rosh Haniqra                 0.9           0.9    1.8       4.5          4.5
# Zefat Har Kenaan             4.6           4.7   13.1       8.0         13.4
# Afeq                         1.9           1.9   13.1      12.2         12.2
# Harashim                     0.3           0.3   15.6      16.0         15.6
# Haifa Technion               0.4           0.4   15.3      25.5         25.6
# Deir Hanna                   1.9           1.9   35.9      35.9         35.9
# Ammiad                       1.6           1.6   45.1      45.2         45.2
# Ayyelet Hashahar             0.1           0.1  100.0     100.0        100.0
# Haifa Refineries             0.2           0.2  100.0     100.0        100.0
#
#                     WS (m/s)  WSmax (m/s)  Ws10mm (m/s)  Ws1mm (m/s)  \
# Dafna                    0.0          0.0           0.0          0.0
# Kefar Blum               0.1          0.1           0.1          0.1
# Eshhar                   0.2          0.2           0.1          0.2
# Shave Ziyyon             0.3          0.3           0.3          0.3
# Merom Golan Picman       0.5          0.5           0.6          0.5
# Gamla                    0.5          0.5           5.9          0.2
# Kefar Giladi             1.6          1.6           1.4          1.4
# Kefar Nahum              0.0          0.0           3.6          0.0
# Avne Etan                0.6          0.7           3.1          3.1
# Elon                     0.4          0.4           0.4          0.4
# Bet Zayda                0.9          0.9           6.1          6.1
# Rosh Haniqra             3.3          3.3           3.3          3.3
# Zefat Har Kenaan         8.0          8.7          13.4         13.4
# Afeq                    11.6         11.6          20.9         11.6
# Harashim                15.6         15.6          15.6         15.6
# Haifa Technion          25.5         25.8          25.5         26.6
# Deir Hanna              36.2         36.6          36.6         36.6
# Ammiad                  45.3         45.3          45.2         45.2
# Ayyelet Hashahar       100.0        100.0         100.0        100.0
# Haifa Refineries       100.0        100.0         100.0        100.0
#
#                     Average Percentage  \
# Dafna                             22.3
# Kefar Blum                        22.3
# Eshhar                            22.4
# Shave Ziyyon                      22.6
# Merom Golan Picman                17.8
# Gamla                             21.7
# Kefar Giladi                      23.0
# Kefar Nahum                       23.1
# Avne Etan                         23.1
# Elon                              23.5
# Bet Zayda                         24.3
# Rosh Haniqra                      25.6
# Zefat Har Kenaan                  24.9
# Afeq                              25.8
# Harashim                          29.5
# Haifa Technion                    20.6
# Deir Hanna                        38.8
# Ammiad                            43.1
# Ayyelet Hashahar                  66.8
# Haifa Refineries                  67.2
#
#                     Average Percentage Excluding Specific Columns
# Dafna                                                         8.2
# Kefar Blum                                                    8.3
# Eshhar                                                        8.4
# Shave Ziyyon                                                  8.6
# Merom Golan Picman                                            8.9
# Gamla                                                         9.1
# Kefar Giladi                                                  9.2
# Kefar Nahum                                                   9.2
# Avne Etan                                                     9.2
# Elon                                                          9.7
# Bet Zayda                                                    10.8
# Rosh Haniqra                                                 12.4
# Zefat Har Kenaan                                             16.3
# Afeq                                                         16.8
# Harashim                                                     17.4
# Haifa Technion                                               18.9
# Deir Hanna                                                   29.1
# Ammiad                                                       34.6
# Ayyelet Hashahar                                             64.6
# Haifa Refineries                                             65.2
